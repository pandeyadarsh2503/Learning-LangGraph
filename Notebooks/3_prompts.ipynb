# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="llama3.1:8b"
)

response = llm.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is Paris.

# %%
from langchain_core.prompts import ChatPromptTemplate

my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant."),
        ("human","What is the capital of France?"),
    ]
)

# %%
prompt_filled = my_prompt.invoke({"topic": "What is the capital of France?"})

# %%
llm.invoke(prompt_filled)
# Out:
# AIMessage(content='The capital of France is Paris! Would you like to know more about Paris or is there something else I can help you with?', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-04-05T03:03:30.6551171Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9739386500, 'load_duration': 514363300, 'prompt_eval_count': 28, 'prompt_eval_duration': 1743862600, 'eval_count': 27, 'eval_duration': 7434401000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019d5b98-4c51-7ea1-839b-bc660b9a8157-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 27, 'total_tokens': 55})

# %%
chain = my_prompt | llm

# %%
chain.invoke({"topic": "What is the capital of France?"})
# Out:
# AIMessage(content='The capital of France is Paris! Would you like to know more about this beautiful city or is there something else I can help you with?', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-04-05T03:03:39.3336856Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8592659700, 'load_duration': 175664400, 'prompt_eval_count': 28, 'prompt_eval_duration': 247398800, 'eval_count': 29, 'eval_duration': 8103499800, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019d5b98-72b1-7993-b4ca-234810a7a3df-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 29, 'total_tokens': 57})
